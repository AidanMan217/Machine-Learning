# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('classification-4.csv')
df.head()
# Out:
#    feature_1  feature_2  target
# 0   1.165908  -1.534980       2
# 1  -2.546390   2.438622       3
# 2   2.065508   1.816396       4
# 3  -4.221937  -4.206057       1
# 4  -0.473280  -1.098304       2

# %%
df_train,df_test = train_test_split(df, test_size=0.25,shuffle=False)

# %%
X_train = df_train.drop('target',axis=1)
X_test = df_test.drop('target',axis=1)

y_train = df_train['target']
y_test = df_test['target']

# %%
plt.figure(figsize=(6,6))
plt.scatter(df_train['feature_1'],df_train['feature_2'],s=10,c=df_train['target'],cmap="viridis",alpha=0.5)
plt.xlabel("x1")
plt.ylabel("x2")
plt.show()

# %%
we
